# %%
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()
    
HTML(styles)

name = 'tidal_harmonic_analysis_t_tide_Canaeia-GLOSS_fromzip'

html = """
<small>
<p> This post was written as an IPython notebook. It is available for <a href="http://ocef
paf.github.com/downloads/notebooks/%s.ipynb">download</a> or as a static <a href="http://
nbviewer.ipython.org/url/ocefpaf.github.com/downloads/notebooks/%s.ipynb">html</a>.</p>
<p></p>
# %s """ % (name, name, html)

# %% [markdown]
# We will use elevation data from the [GLOSS Station 194](https://www.bodc.ac.uk/data/information_and_inventories/gloss_handbook/stations/194/), loading it in a pandas Series to make our job easier.  Check the format of the data below.

# %%
# %%bash
# sed -n 71,83p ./data/gloss_hourly.fmt
# Out:
#           The data records are coded as:
#
#           field          bytes   length             comment
#      -----------------  -------  ------  ------------------------------------
#      station number        1-3     3     exactly 3 digits
#      station version         4     1     letter from A to Z
#      station name          6-9     4     Abbreviated if necessary
#      year                12-15     4
#      month               16-17     2     numerical value
#      day                 18-19     2
#      day record count       20     1     either 1 or 2
#      sea level data      21-80    60     12 sea level values,
#                                          hours 00-11 (1); hours 12-23 (2)

# %%
import os
import zipfile
import numpy as np
import numpy.ma as ma
from zipfile import ZipFile
from datetime import datetime
from pandas import Series, date_range

def basename(fname):
    return os.path.splitext(os.path.basename(fname))[0]


def make_date(data):
    date = str(int(data))[:-1]
    return datetime.strptime(date, '%Y%m%d')


def load_gloss(fname):
    data = np.loadtxt(fname, skiprows=1, usecols=range(2, 15))
    elev = ma.masked_equal(data[:, 1:].ravel(), 9999)
    start = make_date(data[0, 0])
    dates = date_range(start, periods=len(elev), freq='H')
    return Series(elev, index=dates)

# %%
series = Series()
with ZipFile('./data/h281a.zip', 'r') as ziped:
    for fname in sorted(ziped.namelist()):
        if not fname.endswith('/'):  # Skip directories.
            if False:
                with ziped.open(fname) as f:
                    print(f.readline())
            name = basename(fname)
            series = series.append(load_gloss(ziped.open(fname)))

series /= 1e3
series.describe()
# Out:
# count    457699.000000
# mean          1.689822
# std           0.404013
# min           0.140000
# 25%           1.400000
# 50%           1.690000
# 75%           1.980000
# max           4.880000
# dtype: float64

# %%
ax = series.plot(figsize=(20, 4))

# %%
obs = series.ix['1998'] - series.ix['1998'].mean()
ax = obs.plot(figsize=(20, 4))
obs.describe()
elev = obs.values

# %%
from matplotlib.dates import date2num
dates = date_range(datetime.now(), periods=72, freq='H')
tim = date2num(dates.to_pydatetime()) + 366  # Matlab Argh!!

# %%
# %load_ext octavemagic

# %%
# %%octave -i elev -i tim -o tidestruc -o pout -o yout
#
# pkg load all
# addpath(genpath('./t_tide_v1.3beta'))
#
# [tidestruc, pout] = t_tide(elev, 'interval', 1, 'latitude', -25, 'starttime', [1998, 1, 1, 0]);
#
# yout = t_predic(tim, tidestruc);
# Out:
#    number of standard constituents used: 59
#    Points used: 8759 of 8760
#    percent of var residual after lsqfit/var original: 21.04 %
#    Greenwich phase computed with nodal corrections applied to amplitude
#  and phase relative to center time
#    Using nonlinear bootstrapped error estimates
#    Generating prediction with nodal corrections, SNR is 2.000000
# warning: isstr is obsolete and will be removed from a future version of Octave, please use ischar instead
#    percent of var residual after synthesis/var original: 22.20 %
# -----------------------------------
# date: 03-Dec-2013
# nobs = 8760,  ngood = 8759,  record length (days) = 365.00
# start time: 01-Jan-1998
# rayleigh criterion = 1.0
# Greenwich phase computed with nodal corrections applied to amplitude \n and phase relative to center time
#
# x0= 0.000495, x trend= 0
#
# var(x)= 0.15528   var(xp)= 0.12079   var(xres)= 0.034474
# percent var predicted/var original= 77.8 %
#
#      tidal amplitude and phase with 95% CI estimates
#
# tide   freq       amp     amp_err    pha    pha_err     snr
#  SSA  0.0002282    0.0190    0.035   322.09   122.13     0.29
#  MSM  0.0013098    0.0140    0.030   297.52   151.57     0.22
#  MM   0.0015122    0.0214    0.034    47.22   116.61      0.4
#  MSF  0.0028219    0.0372    0.040    34.27    62.34     0.87
#  MF   0.0030501    0.0336    0.037   268.83    79.77     0.81
#  ALP1 0.0343966    0.0017    0.004   110.07   150.71     0.16
#  2Q1  0.0357064    0.0019    0.004    80.29   145.47     0.21
#  SIG1 0.0359087    0.0013    0.004   173.35   176.80     0.11
# *Q1   0.0372185    0.0276    0.006   106.83    11.50       21
#  RHO1 0.0374209    0.0063    0.006   107.09    47.90      1.3
# *O1   0.0387307    0.1091    0.006   127.83     2.55  3.7e+02
#  TAU1 0.0389588    0.0004    0.002   111.39   214.37    0.027
#  BET1 0.0400404    0.0028    0.005   124.19   100.45     0.37
# *NO1  0.0402686    0.0070    0.004    79.47    35.20      3.5
#  CHI1 0.0404710    0.0040    0.005   136.22    74.94     0.64
# *P1   0.0415526    0.0259    0.004   199.37     9.49       35
# *K1   0.0417807    0.0655    0.005   193.64     3.94  1.6e+02
#  PHI1 0.0420089    0.0017    0.003    60.84   141.81     0.24
#  THE1 0.0430905    0.0074    0.005    81.95    37.03        2
#  J1   0.0432929    0.0037    0.004   310.06    76.16      0.7
#  SO1  0.0446027    0.0050    0.005   281.58    60.03     0.96
#  OO1  0.0448308    0.0039    0.007    44.21    98.45     0.35
#  UPS1 0.0463430    0.0023    0.006   308.54   160.00     0.14
#  OQ2  0.0759749    0.0017    0.003   248.00   159.64     0.25
#  EPS2 0.0761773    0.0031    0.004   191.64    94.51     0.55
# *2N2  0.0774871    0.0159    0.005   230.65    17.18       11
# *MU2  0.0776895    0.0255    0.005   240.24    10.57       27
# *N2   0.0789992    0.0633    0.004   247.40     5.16    2e+02
#  NU2  0.0792016    0.0068    0.006   252.11    39.05      1.5
# *M2   0.0805114    0.3717    0.005   184.62     0.75  5.3e+03
# *MKS2 0.0807396    0.0098    0.007   261.48    40.76      2.1
#  LDA2 0.0818212    0.0018    0.004   102.41   135.57     0.18
# *L2   0.0820236    0.0322    0.006   147.88     9.79       29
# *S2   0.0833333    0.2439    0.006   193.29     1.16  1.6e+03
# *K2   0.0835615    0.0767    0.006   182.10     5.03  1.4e+02
#  MSN2 0.0848455    0.0028    0.004   351.48   102.87     0.56
#  ETA2 0.0850736    0.0053    0.007   140.45    93.93     0.65
# *MO3  0.1192421    0.0253    0.008   133.87    15.98       11
# *M3   0.1207671    0.0678    0.006     2.86     4.97  1.3e+02
# *SO3  0.1220640    0.0272    0.008   290.11    16.49       11
# *MK3  0.1222921    0.0265    0.008   261.50    14.84       12
# *SK3  0.1251141    0.0225    0.007    79.22    17.94      9.6
# *MN4  0.1595106    0.0312    0.003   333.90     6.16       87
# *M4   0.1610228    0.0568    0.004    26.92     3.09  2.5e+02
#  SN4  0.1623326    0.0009    0.002   123.94   166.86     0.15
# *MS4  0.1638447    0.0276    0.003   150.66     7.57       63
# *MK4  0.1640729    0.0096    0.004   145.12    25.66      6.3
#  S4   0.1666667    0.0032    0.003   279.38    55.64      1.1
#  SK4  0.1668948    0.0016    0.003   186.53   144.20     0.26
# *2MK5 0.2028035    0.0031    0.002    24.81    41.77      2.1
#  2SK5 0.2084474    0.0006    0.002    69.45   151.01     0.15
#  2MN6 0.2400221    0.0014    0.001   207.21    43.68      1.7
# *M6   0.2415342    0.0030    0.001   135.97    21.49      5.6
# *2MS6 0.2443561    0.0061    0.001   158.82     9.62       29
#  2MK6 0.2445843    0.0015    0.001   164.07    53.95      1.5
# *2SM6 0.2471781    0.0029    0.001   202.96    23.58      5.6
# *MSK6 0.2474062    0.0023    0.002   190.66    45.43      2.1
#  3MK7 0.2833149    0.0015    0.002   313.48    57.17     0.94
# *M8   0.3220456    0.0017    0.001   216.09    42.77      3.1

# %%
import matplotlib.pyplot as plt

fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, sharey=True, sharex=True, figsize=(14, 6))

ax0.plot(obs.index, obs, label=u'Observations')
ax0.legend(numpoints=1, loc='lower right')

ax1.plot(obs.index, pout.squeeze(), alpha=0.5, label=u'Prediction')
ax1.legend(numpoints=1, loc='lower right')

ax2.plot(obs.index, obs-pout.squeeze(), alpha=0.5, label=u'Residue')
_ = ax2.legend(numpoints=1, loc='lower right')

# %%
from pytides.tide import Tide
import pytides.constituent as cons

# %% [markdown]
# These are the NOAA constituents, in the order presented on their website.  Phases and amplitudes (relative to GMT and in degrees and metres).

# %% [markdown]
# # TODO: Change for those at `tidestruc`.

# %%
constituents = [c for c in cons.noaa if c != cons._Z0]
print(' '.join([c.name for c in constituents]))
# Out:
# M2 S2 N2 K1 M4 O1 M6 MK3 S4 MN4 nu2 S6 mu2 2N2 OO1 lambda2 S1 M1 J1 Mm Ssa Sa MSF Mf rho1 Q1 T2 R2 2Q1 P1 2SM2 M3 L2 2MK3 K2 M8 MS4

# %%
amplitudes = tidestruc['tidecon'][:, 0]
phases = tidestruc['tidecon'][:, 2]
print(' '.join(tidestruc['name']))
# Out:
# SSA  MSM  MM   MSF  MF   ALP1 2Q1  SIG1 Q1   RHO1 O1   TAU1 BET1 NO1  CHI1 P1   K1   PHI1 THE1 J1   SO1  OO1  UPS1 OQ2  EPS2 2N2  MU2  N2   NU2  M2   MKS2 LDA2 L2   S2   K2   MSN2 ETA2 MO3  M3   SO3  MK3  SK3  MN4  M4   SN4  MS4  MK4  S4   SK4  2MK5 2SK5 2MN6 M6   2MS6 2MK6 2SM6 MSK6 3MK7 M8

# %%
amplitudes.max()
# Out:
# 0.37167002442732555

# %%
published_phases = [115.7,140.7,92.6,192,145.5,220.6,159.9,202.8,152.3,117.2,92,0,0,69.7,224.5,141.7,121.9,
228.4,252.1,0,60.1,135.5,0,0,204.5,212.2,112.3,141.8,249.1,211.1,75.1,181.4,140.4,202.4,141.8,155,160.9]

published_amplitudes = [1.142,0.189,0.241,0.1,0.036,0.066,0.08,0.01,0.004,0.022,0.052,0,0,0.03,0.007,0.025,0.009,
0.005,0.008,0,0.024,0.065,0,0,0.004,0.017,0.015,0.002,0.002,0.032,0.003,0.007,0.07,0.009,0.053,0.007,0.008]

# %% [markdown]
# We can add a constant offset (e.g. for a different datum, we will use relative to MLLW).

# %%
MTL, MLLW = 5.113, 3.928
offset = MTL - MLLW
constituents.append(cons._Z0)
published_phases.append(0)
published_amplitudes.append(offset)

# %% [markdown]
# Build the model.

# %%
assert(len(constituents) == len(published_phases) == len(published_amplitudes))
model = np.zeros(len(constituents), dtype = Tide.dtype)
model['constituent'] = constituents
model['amplitude'] = published_amplitudes
model['phase'] = published_phases

tide = Tide(model=model, radians=False)

elev = tide.at(dates)

# %%
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(dates, elev, 'k', label='pytides')
ax.plot(dates, yout.squeeze(), 'b', label='t_predic')
_ = ax.legend()

# %%
HTML(html)
# Out:
# <small>
# <p> This post was written as an IPython notebook. It is available for <a href="http://ocef
# paf.github.com/downloads/notebooks/tidal_harmonic_analysis_t_tide_Canaeia-GLOSS_fromzip.ipynb">download</a> or as a static <a href="http://
# nbviewer.ipython.org/url/ocefpaf.github.com/downloads/notebooks/tidal_harmonic_analysis_t_tide_Canaeia-GLOSS_fromzip.ipynb">html</a>.</p>
# <p></p>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
# alt="Creative Commons License" style="border-width:0"
# src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
# xmlns:dct="http://purl.org/dc/terms/"
# property="dct:title">python4oceanographers</span> by <a
# xmlns:cc="http://creativecommons.org/ns#" href="http://ocefpaf.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">Filipe Fernandes</a> is
# licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
# Attribution-ShareAlike 4.0 International License</a>.<br />Based on a work at <a
# xmlns:dct="http://purl.org/dc/terms/" href="http://ocefpaf.github.io/"
# rel="dct:source">http://ocefpaf.github.io/</a>.
